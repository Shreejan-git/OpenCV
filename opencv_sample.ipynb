# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.6.0'

# %% [markdown]
# # Two pre-built samples provided my OpenCV to get started with OpenCV

# %%
# !python hist.py
#to see the histogram of an image
# Out:
#  This is a sample for histogram plotting for RGB images and grayscale images for better understanding of colour distribution
#
# Benefit : Learn how to draw histogram of images
#           Get familier with cv.calcHist, cv.equalizeHist,cv.normalize and some drawing functions
#
# Level : Beginner or Intermediate
#
# Functions : 1) hist_curve : returns histogram of an image drawn as curves
#             2) hist_lines : return histogram of an image drawn as bins ( only for grayscale images )
#
# Usage : python hist.py <image_file>
#
# Abid Rahman 3/14/12 debug Gary Bradski
#
# usage : python hist.py <image_file>
# [ WARN:0@0.006] global /io/opencv/modules/core/src/utils/samples.cpp (61) findFile cv::samples::findFile('lena.jpg') => '/home/shreejan/Desktop/opencv_project/opencv-4.6.0/samples/python/../../samples/data/lena.jpg'
#  Histogram plotting
#
#     Keymap :
#
#     a - show histogram for color image in curve mode
#
#     b - show histogram in bin mode
#
# ...

# %% [markdown]
# ![Screenshot%20from%202022-11-05%2016-23-00.png](attachment:Screenshot%20from%202022-11-05%2016-23-00.png)

# %% [markdown]
# ![Screenshot%20from%202022-11-05%2016-23-11.png](attachment:Screenshot%20from%202022-11-05%2016-23-11.png)

# %%
# !python opt_flow.py 0
#this is for optical flow sample
#this tracks the real-time movement through the webcam of the laptop
# Out:
# example to show optical flow
#
# USAGE: opt_flow.py [<video_source>]
#
# Keys:
#  1 - toggle HSV flow visualization
#  2 - toggle glitch
#
# Keys:
#     ESC    - exit
#
# Done

# %% [markdown]
# ![Screenshot%20from%202022-11-05%2016-31-41.png](attachment:Screenshot%20from%202022-11-05%2016-31-41.png)
