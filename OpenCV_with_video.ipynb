# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
# https://www.pexels.com/video/woman-smelling-a-perfume-7192338/
# to get the downloadable video

# %%
cap = cv2.VideoCapture('video/video_opencv.mp4')

# %%
ret, frame = cap.read()

# %%
ret #if the ret returns True, then that means, we are read the video well.
# Out:
# True

# %%
frame.shape 
#every video is just the combinations of multiple images passing  thorugh our screen in certain FPS.
# Out:
# (2160, 3840, 3)

# %%
plt.imshow(frame) #

# %% [markdown]
# #since the OpenCV has blue channel at first (BGR),
